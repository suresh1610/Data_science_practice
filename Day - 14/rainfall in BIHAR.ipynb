# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\FP2_RainFall\rainfall in india 1901-2015.csv")
df
# Out:
#       index                SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY  \
# 0         0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8
# 1         1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1
# 2         2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1
# 3         3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5
# 4         4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5
# ...     ...                        ...   ...   ...    ...   ...    ...    ...
# 4111   4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2
# 4112   4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2
# 4113   4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3
# 4114   4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4
# 4115   4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1
#
# ...

# %%
df.columns
# Out:
# Index(['index', 'SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY',
#        'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
#        'Mar-May', 'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        4116 non-null   int64
#  1   SUBDIVISION  4116 non-null   object
#  2   YEAR         4116 non-null   int64
#  3   JAN          4112 non-null   float64
#  4   FEB          4113 non-null   float64
#  5   MAR          4110 non-null   float64
#  6   APR          4112 non-null   float64
#  7   MAY          4113 non-null   float64
#  8   JUN          4111 non-null   float64
#  9   JUL          4109 non-null   float64
#  10  AUG          4112 non-null   float64
#  11  SEP          4110 non-null   float64
#  12  OCT          4109 non-null   float64
#  13  NOV          4105 non-null   float64
#  14  DEC          4106 non-null   float64
#  15  ANNUAL       4090 non-null   float64
#  16  Jan-Feb      4110 non-null   float64
#  17  Mar-May      4107 non-null   float64
# ...

# %%
df1 = df[897:1011]
df1
# Out:
#       index SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN    JUL  \
# 897     897       BIHAR  1901  51.8  19.6  11.9   1.1   65.6   66.3  245.9
# 898     898       BIHAR  1902   4.6   0.7  24.3  17.3   66.3  118.2  361.0
# 899     899       BIHAR  1903   5.3   4.7   2.0   4.7   28.2  192.9  115.0
# 900     900       BIHAR  1904   6.3   1.7   3.5   5.3  118.7  191.6  394.4
# 901     901       BIHAR  1905  16.0  30.1  32.6  21.4   77.5   50.5  409.1
# ...     ...         ...   ...   ...   ...   ...   ...    ...    ...    ...
# 1006   1006       BIHAR  2010   0.1   1.1   0.2   6.5   44.4   80.9  191.2
# 1007   1007       BIHAR  2011   4.2   7.7   9.2  23.9   74.5  211.0  241.1
# 1008   1008       BIHAR  2012  18.1   2.7   7.3  20.4   18.8   96.2  354.0
# 1009   1009       BIHAR  2013   5.1  22.6   0.6  32.3   89.5  183.3  182.0
# 1010   1010       BIHAR  2014  17.0  33.5   8.4   0.7  103.9  115.2  265.4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        4116 non-null   int64
#  1   SUBDIVISION  4116 non-null   object
#  2   YEAR         4116 non-null   int64
#  3   JAN          4112 non-null   float64
#  4   FEB          4113 non-null   float64
#  5   MAR          4110 non-null   float64
#  6   APR          4112 non-null   float64
#  7   MAY          4113 non-null   float64
#  8   JUN          4111 non-null   float64
#  9   JUL          4109 non-null   float64
#  10  AUG          4112 non-null   float64
#  11  SEP          4110 non-null   float64
#  12  OCT          4109 non-null   float64
#  13  NOV          4105 non-null   float64
#  14  DEC          4106 non-null   float64
#  15  ANNUAL       4090 non-null   float64
#  16  Jan-Feb      4110 non-null   float64
#  17  Mar-May      4107 non-null   float64
# ...

# %%
df1.isna().sum()
# Out:
# index          0
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# dtype: int64

# %%
df2 = df1.fillna(0)
df2
# Out:
#       index SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN    JUL  \
# 897     897       BIHAR  1901  51.8  19.6  11.9   1.1   65.6   66.3  245.9
# 898     898       BIHAR  1902   4.6   0.7  24.3  17.3   66.3  118.2  361.0
# 899     899       BIHAR  1903   5.3   4.7   2.0   4.7   28.2  192.9  115.0
# 900     900       BIHAR  1904   6.3   1.7   3.5   5.3  118.7  191.6  394.4
# 901     901       BIHAR  1905  16.0  30.1  32.6  21.4   77.5   50.5  409.1
# ...     ...         ...   ...   ...   ...   ...   ...    ...    ...    ...
# 1006   1006       BIHAR  2010   0.1   1.1   0.2   6.5   44.4   80.9  191.2
# 1007   1007       BIHAR  2011   4.2   7.7   9.2  23.9   74.5  211.0  241.1
# 1008   1008       BIHAR  2012  18.1   2.7   7.3  20.4   18.8   96.2  354.0
# 1009   1009       BIHAR  2013   5.1  22.6   0.6  32.3   89.5  183.3  182.0
# 1010   1010       BIHAR  2014  17.0  33.5   8.4   0.7  103.9  115.2  265.4
#
# ...

# %%
df2.isna().sum()
# Out:
# index          0
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['index', 'SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY',
#        'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
#        'Mar-May', 'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
df3 = df2[['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY',
       'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
       'Mar-May', 'Jun-Sep', 'Oct-Dec']]

# %%
df3[['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY',
       'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
       'Mar-May', 'Jun-Sep', 'Oct-Dec']].plot.line(figsize=(13,8))
# Out:
# <AxesSubplot:>

# %%
df3.plot.bar(figsize=(13,8))
# Out:
# <AxesSubplot:>

# %%
df4 = df3['ANNUAL']

# %%
df4.plot.pie(figsize=(40,8))
# Out:
# <AxesSubplot:ylabel='ANNUAL'>

# %%
df3.plot.box(figsize=(13,8))
# Out:
# <AxesSubplot:>

# %%
df3.plot.hist(figsize=(13,8))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.heatmap(df2.corr())
# Out:
# <AxesSubplot:>
